# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report
from sklearn.decomposition import LatentDirichletAllocation
import requests
import random

# %%
df = pd.read_csv('memes.csv')

# %%
missing_values = df.isnull().sum()

# %%
df = df.dropna()

# %%
df['Description'] = df['Text0'] + ' ' + df['Text1']

# %%
train_data, test_data, train_target, test_target = train_test_split(
    df['Description'], df['Industry'], test_size=0.2, random_state=42
)

# %%
model = make_pipeline(TfidfVectorizer(), MultinomialNB())
model.fit(train_data, train_target)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer()),
#                 ('multinomialnb', MultinomialNB())])

# %%
# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Print the value counts
print(df['Industry'].value_counts())
# Out:
# Industry
# Entertainment                  142
# Art                            142
# Programmer                     132
# Finance                        131
# Food                           130
# Education                      129
# Business                       129
# Fitness                        129
# Technology                     129
# Travel                         128
# Meditation                     128
# Student                        128
# Photography                    128
# Engineer                       128
# Beauty                         128
# Web Development                127
# Influencers                    123
# Healthcare                      79
# Law                             66
# Marketing                       59
# Work place                      28
# Culinary                        23
# Communication                   21
# Gardening                       20
# DIY                             18
# Single                          17
# Cybersecurity                   16
# Home Improvement                13
# Media                           13
# Pet Owner                       13
# Science                         12
# Fashion                         12
# Commerce                        11
# Internet User                   11
# Influencer                      10
# Remote Work                     10
# Work                            10
# Baker                            9
# Listener                         8
# Retail                           8
# Events                           8
# Programming                      8
# Commuter                         8
# Music                            7
# Baking                           7
# Office Worker                    7
# Health                           7
# Gaming                           7
# Wellness                         6
# Mental Health                    6
# Employment                       6
# Self-Improvement                 6
# History                          6
# Cook                             6
# Psychology                       6
# Language Learning                6
# Driver                           6
# Mindfulness                      6
# Advocate                         5
# Writing                          5
# IT Professional                  5
# Early Riser                      5
# Nutrition                        5
# Photographer                     5
# Home Maintenance                 5
# Work From Home                   5
# Automotive                       5
# Students                         5
# Beverages                        5
# Film                             5
# Relationships                    5
# Texter                           5
# Online Gaming                    5
# Organization                     5
# Home Decor                       4
# Literature                       4
# Coffee Enthusiast                4
# Online Workouts                  4
# Driving                          4
# Bidder                           4
# Industry                         4
# Research                         4
# Transportation                   4
# Home Entertainment               4
# Host                             4
# Visitor                          4
# Food Lover                       4
# Music Fan                        4
# Reading                          3
# Youtuber                         3
# Pet Care                         3
# Security                         3
# Foodie                           3
# Social                           3
# Pets                             3
# Celebration                      3
# Job Search                       3
# Remote Workers                   2
# Hobbies                          2
# Energy                           2
# Commute                          2
# Lazy Cooks                       2
# Coffee Lover                     2
# Plant Parent                     2
# Business                         2
# Podcasting in Photography        2
# Real Estate                      2
# Web Developer                    2
# Photographers                    2
# Smartphone Users                 2
# Timekeeping                      2
# Filmmaking                       2
# Creativity                       2
# Laundry Day                      2
# Share Market                     2
# Shopping                         2
# Procrastinating Students         2
# Trivia                           2
# Social Media Junkie              1
# Teacher                          1
# Socializing                      1
# Semester Surprises               1
# Inbox Overflow                   1
# Politics                         1
# Fashion Dilemma                  1
# Environment                      1
# Shopaholic                       1
# Science Majors                   1
# Investor                         1
# Coupon Clipping                  1
# Virtual Classroom Struggles      1
# Digital Age Woes                 1
# Movie Nights                     1
# Unlucky Runners                  1
# Job                              1
# Music Lover                      1
# Tech Frustration                 1
# Forgetful Classmates             1
# Dieter's Dilemma                 1
# Adventure Seeker                 1
# Procrastinator                   1
# Meme marketing                   1
# Gamer                            1
# Goal-Getter                      1
# Chocoholic                       1
# Dog Lover                        1
# Identity Crisis                  1
# Socializing Students             1
# Outdoor Events                   1
# Strategic Seating Choices        1
# Sock Enthusiasts                 1
# Desperate for Extra Credit       1
# Unorganized Students             1
# Lifestyle                        1
# Rainy Days                       1
# Proofreading Assistance          1
# Citation Overload                1
# Exams                            1
# Marking Every Line               1
# Umbrella Salesmen                1
# Impromptu Study Aids             1
# English Teacher                  1
# Fuel for Brainpower              1
# Beauty Enthusiast                1
# Workaholic                       1
# Career                           1
# Meme Lifestyle                   1
# Bookworm Struggles               1
# Food and Beverage                1
# Unread Messages                  1
# Fear of the Blank Page           1
# Last-Minute Assignments          1
# Wine                             1
# Phone User                       1
# Home Security                    1
# Historical References            1
# Mobile Gym                       1
# Quiet Places                     1
# Navigating the Maze              1
# Outdoor Activities               1
# Productivity Gurus               1
# Dishwashing                      1
# Breakfast Maker                  1
# Agriculture                      1
# Work from Home                   1
# Home Appliances                  1
# Summer Picnics                   1
# Meteorologist                    1
# Philosophy of Love               1
# Shopper                          1
# Flu Season                       1
# Phone Etiquette                  1
# TV Series Fan                    1
# Couch Potatoes                   1
# Broke Students                   1
# Services                         1
# Lab Coat Fashion                 1
# DIY Enthusiasts                  1
# Environmentalists                1
# Generation                       1
# Dance                            1
# Travel                           1
# Silent Study Struggles           1
# Texting                          1
# Couch Potato                     1
# Night Owl                        1
# Forgetful Students               1
# Social Media                     1
# Chef                             1
# Culinary Arts                    1
# Fitness Enthusiast               1
# Gadget Lovers                    1
# law                              1
# Name: count, dtype: int64

# %%
# Make predictions on the test set
predictions = model.predict(test_data)

# Evaluate the model
print(classification_report(test_target, predictions))

predictions = model.predict(test_data)

# Evaluate the model
accuracy = (predictions == test_target).mean()
print(f"Model Accuracy: {accuracy}")
# Out:
#                           precision    recall  f1-score   support
#
#                 Advocate       0.00      0.00      0.00         2
#           Allergy Season       0.00      0.00      0.00         1
#                      Art       0.35      0.90      0.50        20
#               Automotive       0.00      0.00      0.00         1
#                    Baker       0.00      0.00      0.00         1
#         Bargain Shoppers       0.00      0.00      0.00         1
#                   Beauty       0.78      0.97      0.86        29
#        Beauty Enthusiast       0.00      0.00      0.00         1
#                   Bidder       0.00      0.00      0.00         1
#                  Bingers       0.00      0.00      0.00         1
#              Book Lovers       0.00      0.00      0.00         1
#                 Business       0.77      0.89      0.83        27
#      Campus Weather Woes       0.00      0.00      0.00         1
#              Celebration       0.00      0.00      0.00         1
#               Chocoholic       0.00      0.00      0.00         1
#        Coffee Enthusiast       0.00      0.00      0.00         1
#                 Commerce       0.00      0.00      0.00         2
#          Online Shopping       0.00      0.00      0.00         1
#          Online Workouts       0.00      0.00      0.00         1
#                Optometry       0.00      0.00      0.00         1
#             Organization       0.00      0.00      0.00         1
#                 Pandemic       0.00      0.00      0.00         1
#                 Pet Care       0.00      0.00      0.00         2
#                Pet Owner       0.00      0.00      0.00         4
#                     Pets       0.00      0.00      0.00         1
#       Philosophy of Love       0.00      0.00      0.00         1
#             Photographer       0.00      0.00      0.00         3
#              Photography       0.34      0.83      0.49        24
#             Plant Parent       0.00      0.00      0.00         1
#            Plant Parents       0.00      0.00      0.00         1
# Procrastinating Students       0.00      0.00      0.00         1
#               Programmer       0.56      0.96      0.70        26
#              Programming       0.00      0.00      0.00         2
#             Quiet Places       0.00      0.00      0.00         1
#                  Reading       0.00      0.00      0.00         2
#            Relationships       0.00      0.00      0.00         3
#              Remote Work       0.00      0.00      0.00         2
#                 Research       0.00      0.00      0.00         1
#                   Retail       0.00      0.00      0.00         2
#                  Science       0.00      0.00      0.00         4
#       Semester Surprises       0.00      0.00      0.00         1
#             Share Market       0.00      0.00      0.00         1
#                 Shopping       0.00      0.00      0.00         1
#                   Single       0.00      0.00      0.00         4
#         Smartphone Users       0.00      0.00      0.00         1
#             Social Media       0.00      0.00      0.00         1
#                  Student       0.33      0.89      0.48        18
#                 Teacher        0.00      0.00      0.00         1
#               Technology       0.80      0.65      0.71        31
#                  Texting       0.00      0.00      0.00         1
#                Transport       0.00      0.00      0.00         1
#           Transportation       0.00      0.00      0.00         2
#                   Travel       0.61      0.80      0.69        25
#                  Travel        0.00      0.00      0.00         1
#                 Traveler       0.00      0.00      0.00         1
#                   Trivia       0.00      0.00      0.00         1
#          Unread Messages       0.00      0.00      0.00         1
#     Unwatched Recordings       0.00      0.00      0.00         1
#            Urban Drivers       0.00      0.00      0.00         1
#            Web Developer       0.00      0.00      0.00         1
#          Web Development       0.54      0.81      0.65        26
#                 Wellness       0.00      0.00      0.00         2
#                     Work       0.00      0.00      0.00         2
#           Work From Home       0.00      0.00      0.00         1
#           Work from Home       0.00      0.00      0.00         1
#               Work place       0.00      0.00      0.00         2
#                  Writing       0.00      0.00      0.00         1
#                 Youtuber       0.00      0.00      0.00         2
#                      law       0.00      0.00      0.00         1
#
#                 accuracy                           0.55       652
#                macro avg       0.09      0.11      0.09       652
#             weighted avg       0.45      0.55      0.47       652
#
# Model Accuracy: 0.5506134969325154
# C:\Users\Rishabh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Rishabh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Rishabh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Single paragraph as input
new_description = "I am coder"

# Predict the industry for the input paragraph
new_prediction = model.predict([new_description])

# Retrieve memes related to the predicted industry
predicted_memes = df[df['Industry'] == new_prediction[0]]

# Randomly select 10 memes from the predicted industry
selected_memes = predicted_memes.sample(n=10)

for index, data in selected_memes.iterrows():
    url = f"https://api.imgflip.com/caption_image?template_id={data['Meme_id']}&username=rishabhnahar&password=QTyk9F6g!YYbgBz&text0={data['Text0']}&text1={data['Text1']}"
    print(data['Meme_id'])
    response = requests.post(url)
    if response.status_code == 200:
        print("API Response:")
        print(response.json()['data']['url'])
    else:
        # Print an error message if the request was not successful
        print(f"Error: {response.status_code}, {response.text}")
# Out:
# 166969924
# API Response:
# https://i.imgflip.com/8o8dsr.jpg
# 166969924
# API Response:
# https://i.imgflip.com/8o8dsx.jpg
# 166969924
# API Response:
# https://i.imgflip.com/8o8dsz.jpg
# 89370399
# API Response:
# https://i.imgflip.com/8o8dt5.jpg
# 259237855
# API Response:
# https://i.imgflip.com/8o8dt8.jpg
# 259237855
# API Response:
# https://i.imgflip.com/8o8dte.jpg
# 259237855
# API Response:
# https://i.imgflip.com/8o8dtl.jpg
# 89370399
# API Response:
# https://i.imgflip.com/8o8dtu.jpg
# 166969924
# API Response:
# https://i.imgflip.com/8o8du1.jpg
# 166969924
# API Response:
# https://i.imgflip.com/8o8du8.jpg

# %%
# # New input description
# new_description = "I am Student"

# # Make predictions for the new input
# new_prediction = model.predict([new_description])

# # Display the predicted industry category
# print(f"Predicted Industry: {new_prediction}")

# # Retrieve memes related to the predicted industry
# predicted_memes = df[df['Industry'] == new_prediction[0]]


# # Display the memes
# for index, data in predicted_memes.iterrows():
#     meme_id = data['Meme_id']
#     text0 = data['Text0']
#     text1 = data['Text1']

#     # Construct the URL
#     url = f"https://api.imgflip.com/caption_image?template_id={meme_id}&username=rishabhnahar&password=QTyk9F6g!YYbgBz&text0={text0}&text1={text1}"

#     # print(url) # print(data.Meme_id)
#     # Make the API call
#     response = requests.post(url)

#     # Check if the request was successful (status code 200)
#     if response.status_code == 200:
#         # Print the response content (usually in JSON format)
#         print("API Response:")
#         print(response.json()['data']['url'])
#     else:
#         # Print an error message if the request was not successful
#         print(f"Error: {response.status_code}, {response.text}")

# %%
import pandas as pd
import random
from nltk import word_tokenize
from collections import defaultdict

def load_meme_dataset(file_path):
    df = pd.read_csv(file_path)
    return df

def train_markov_chain_model(meme_dataset):
    model = defaultdict(list)

    # Tokenize text0 and text1 and build the Markov chain model
    for _, row in meme_dataset.iterrows():
        tokens0 = word_tokenize(row['Text0'])
        tokens1 = word_tokenize(row['Text1'])
        tokens2 = word_tokenize(row['Industry'])

        for i in range(len(tokens0) - 1):
            model[tokens0[i]].append(tokens0[i + 1])

        for i in range(len(tokens1) - 1):
            model[tokens1[i]].append(tokens1[i + 1])
            
        for i in range(len(tokens2) - 1):
            model[tokens2[i]].append(tokens2[i + 1])


    return model

def generate_markov_text(user_input, markov_model, max_length=15):
    words = word_tokenize(user_input.lower())
    generated_text = words.copy()

    for _ in range(max_length):
        current_word = generated_text[-1]
        next_word_options = markov_model.get(current_word, [])
        
        if not next_word_options:
            break  # Stop if no options are available for the current word
        
        next_word = random.choice(next_word_options)
        generated_text.append(next_word)

    return ' '.join(generated_text)


# Example user input
user_input = "Write a meme on my coding journey"
markov_model = train_markov_chain_model(df)

generated_text = generate_markov_text(user_input, markov_model)
print("Generated Meme-like Text:", generated_text)
# Out:
# Generated Meme-like Text: write a meme on my coding journey ?
